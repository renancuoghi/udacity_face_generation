# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Downloading mnist: 9.92MB [00:25, 391kB/s]
# Extracting mnist: 100%|██████████| 60.0k/60.0k [00:26<00:00, 2.29kFile/s]
# Downloading celeba: 1.44GB [56:57, 422kB/s]
# Extracting celeba...

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.8.0
# /home/renan/.local/lib/python3.5/site-packages/ipykernel_launcher.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    real_ph_inputs = tf.placeholder(tf.float32, 
                                 (None, image_width, image_height, image_channels),
                                'real_inputs')
    
    z_ph_inputs = tf.placeholder(tf.float32, 
                              (None, z_dim), 
                              'z_inputs')
    
    lr = tf.placeholder(tf.float32, name='learning_rate')

    return real_ph_inputs, z_ph_inputs, lr


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    with tf.variable_scope('discriminator', reuse=reuse):        
        alpha = 0.2
        
        h1 = tf.layers.conv2d(images, 64, 5, 2, 'same')
        h1 = tf.maximum(alpha * h1, h1)
        
        h2 = tf.layers.conv2d(h1, 128, 5, 2, 'same')
        h2 = tf.layers.batch_normalization(h2, training=True)
        h2 = tf.maximum(alpha * h2, h2)
        
        h3 = tf.layers.conv2d(h2, 256, 5, 2, 'same')
        h3 = tf.layers.batch_normalization(h3, training=True)
        h3 = tf.maximum(alpha * h3, h3)
        
        logits = tf.layers.dense(tf.reshape(h3, (-1, 4*4*256)), 1)
        out = tf.sigmoid(logits)
        
    return out, logits

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    with tf.variable_scope('generator', reuse=not is_train):
        alpha = 0.2
    
        h1 = tf.layers.dense(z, 2*2*512)
        h1 = tf.reshape(h1, (-1, 2, 2, 512))
        h1 = tf.layers.batch_normalization(h1, training=is_train)
        h1 = tf.maximum(alpha * h1, h1)
    
        h2 = tf.layers.conv2d_transpose(h1, 256, 5, 2, 'valid')
        h2 = tf.layers.batch_normalization(h2, training=is_train)
        h2 = tf.maximum(alpha * h2, h2)
    
        h3 = tf.layers.conv2d_transpose(h2, 128, 5, 2, 'same')
        h3 = tf.layers.batch_normalization(h3, training=is_train)
        h3 = tf.maximum(alpha * h3, h3)
    
        logits = tf.layers.conv2d_transpose(h3, out_channel_dim, 5, 2, 'same')

        return tf.tanh(logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)
    
    sig_cross_d_real = tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                               labels=tf.ones_like(d_model_real))    
    d_loss_real = tf.reduce_mean(sig_cross_d_real)
    
    sig_cross_d_fake = tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                               labels=tf.zeros_like(d_model_fake))
    d_loss_fake = tf.reduce_mean(sig_cross_d_fake)
    
    g_loss_sig_cross = tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                               labels=tf.ones_like(d_model_fake))
    g_loss = tf.reduce_mean(g_loss_sig_cross)
    
    d_loss = d_loss_real + d_loss_fake

    return d_loss, g_loss

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]
    
    d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
    
    ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    g_updates = [opt for opt in ops if opt.name.startswith('generator')]
    
    with tf.control_dependencies(g_updates):
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1).minimize(g_loss, var_list=g_vars)
        
    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    _, img_width, img_height, img_channels = data_shape
    
    real_input, z_input, lr = model_inputs(img_width, img_height, img_channels, z_dim)
    
    d_loss, g_loss = model_loss(real_input, z_input, img_channels)
    d_opt, g_opt = model_opt(d_loss, g_loss, learning_rate, beta1)
    
    steps = 0
    print_every = 10
    show_every = 100
    losses = []
    n_images = 25
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                steps += 1
                batch_images *= 2.0
                z_sample = np.random.uniform(-1, 1, (batch_size, z_dim))
                
                _ = sess.run(d_opt, feed_dict={real_input: batch_images, z_input: z_sample, lr: learning_rate})
                _ = sess.run(g_opt, feed_dict={z_input: z_sample, lr: learning_rate})
                
                if steps % print_every == 0:
                    train_loss_d = d_loss.eval({z_input: z_sample, real_input: batch_images})
                    train_loss_g = g_loss.eval({z_input: z_sample})
                    
                    print("Epoch {}/{}...".format(epoch_i+1, epoch_count),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    losses.append((train_loss_d, train_loss_g))
                
                if steps % show_every == 0:
                    show_generator_output(sess, n_images, z_input, img_channels, data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 3.4625... Generator Loss: 0.1413
# Epoch 1/2... Discriminator Loss: 0.8228... Generator Loss: 6.2116
# Epoch 1/2... Discriminator Loss: 0.3062... Generator Loss: 3.8377
# Epoch 1/2... Discriminator Loss: 0.5335... Generator Loss: 1.8188
# Epoch 1/2... Discriminator Loss: 1.0526... Generator Loss: 0.7369
# Epoch 1/2... Discriminator Loss: 0.3902... Generator Loss: 2.6912
# Epoch 1/2... Discriminator Loss: 0.2995... Generator Loss: 2.4729
# Epoch 1/2... Discriminator Loss: 0.5536... Generator Loss: 1.6415
# Epoch 1/2... Discriminator Loss: 0.6535... Generator Loss: 1.8215
# Epoch 1/2... Discriminator Loss: 0.2961... Generator Loss: 2.6637
# Epoch 1/2... Discriminator Loss: 1.2291... Generator Loss: 4.8665
# Epoch 1/2... Discriminator Loss: 0.7555... Generator Loss: 1.2164
# Epoch 1/2... Discriminator Loss: 0.4928... Generator Loss: 2.5217
# Epoch 1/2... Discriminator Loss: 0.5444... Generator Loss: 2.1956
# Epoch 1/2... Discriminator Loss: 0.7633... Generator Loss: 1.7450
# Epoch 1/2... Discriminator Loss: 0.4115... Generator Loss: 2.5007
# Epoch 1/2... Discriminator Loss: 0.2966... Generator Loss: 2.5788
# Epoch 1/2... Discriminator Loss: 2.3320... Generator Loss: 8.4591
# Epoch 1/2... Discriminator Loss: 0.8160... Generator Loss: 1.9859
# Epoch 1/2... Discriminator Loss: 0.9533... Generator Loss: 3.8019
# Epoch 1/2... Discriminator Loss: 0.5225... Generator Loss: 3.1551
# Epoch 1/2... Discriminator Loss: 0.8914... Generator Loss: 1.4493
# Epoch 1/2... Discriminator Loss: 0.6464... Generator Loss: 2.6130
# Epoch 1/2... Discriminator Loss: 0.7919... Generator Loss: 1.4088
# Epoch 1/2... Discriminator Loss: 1.1100... Generator Loss: 3.2931
# Epoch 1/2... Discriminator Loss: 0.7466... Generator Loss: 3.2761
# Epoch 1/2... Discriminator Loss: 2.2321... Generator Loss: 6.0425
# Epoch 1/2... Discriminator Loss: 0.6096... Generator Loss: 2.6145
# Epoch 1/2... Discriminator Loss: 1.0556... Generator Loss: 3.1181
# Epoch 1/2... Discriminator Loss: 0.5117... Generator Loss: 1.8536
# Epoch 1/2... Discriminator Loss: 0.6061... Generator Loss: 2.1796
# Epoch 1/2... Discriminator Loss: 0.9823... Generator Loss: 2.4484
# Epoch 1/2... Discriminator Loss: 0.8742... Generator Loss: 0.9603
# Epoch 1/2... Discriminator Loss: 0.6001... Generator Loss: 1.7569
# Epoch 1/2... Discriminator Loss: 0.8762... Generator Loss: 1.2350
# Epoch 1/2... Discriminator Loss: 0.8725... Generator Loss: 1.0009
# Epoch 1/2... Discriminator Loss: 0.7523... Generator Loss: 1.7422
# Epoch 1/2... Discriminator Loss: 0.8397... Generator Loss: 2.2432
# Epoch 1/2... Discriminator Loss: 0.5573... Generator Loss: 1.7728
# Epoch 1/2... Discriminator Loss: 0.9479... Generator Loss: 1.3040
# Epoch 1/2... Discriminator Loss: 0.7170... Generator Loss: 1.2552
# Epoch 1/2... Discriminator Loss: 0.9546... Generator Loss: 0.9145
# Epoch 1/2... Discriminator Loss: 1.4069... Generator Loss: 2.9759
# Epoch 1/2... Discriminator Loss: 0.9021... Generator Loss: 1.2661
# Epoch 1/2... Discriminator Loss: 1.2575... Generator Loss: 0.6310
# Epoch 1/2... Discriminator Loss: 0.8371... Generator Loss: 1.1209
# Epoch 2/2... Discriminator Loss: 0.9805... Generator Loss: 0.8245
# Epoch 2/2... Discriminator Loss: 0.8809... Generator Loss: 1.0663
# Epoch 2/2... Discriminator Loss: 0.8405... Generator Loss: 0.9713
# Epoch 2/2... Discriminator Loss: 0.9414... Generator Loss: 2.0230
# Epoch 2/2... Discriminator Loss: 1.1450... Generator Loss: 3.1996
# Epoch 2/2... Discriminator Loss: 0.7635... Generator Loss: 1.7161
# Epoch 2/2... Discriminator Loss: 1.0394... Generator Loss: 1.9523
# Epoch 2/2... Discriminator Loss: 0.8375... Generator Loss: 1.2444
# Epoch 2/2... Discriminator Loss: 0.9666... Generator Loss: 0.8823
# Epoch 2/2... Discriminator Loss: 0.9496... Generator Loss: 1.1312
# Epoch 2/2... Discriminator Loss: 0.9132... Generator Loss: 0.9299
# Epoch 2/2... Discriminator Loss: 0.8184... Generator Loss: 1.4751
# Epoch 2/2... Discriminator Loss: 1.6876... Generator Loss: 0.3282
# Epoch 2/2... Discriminator Loss: 0.7156... Generator Loss: 1.5795
# Epoch 2/2... Discriminator Loss: 1.6434... Generator Loss: 0.3736
# Epoch 2/2... Discriminator Loss: 1.0419... Generator Loss: 1.7471
# Epoch 2/2... Discriminator Loss: 0.9558... Generator Loss: 0.8042
# Epoch 2/2... Discriminator Loss: 1.2795... Generator Loss: 0.5416
# Epoch 2/2... Discriminator Loss: 0.7959... Generator Loss: 0.9723
# Epoch 2/2... Discriminator Loss: 0.9519... Generator Loss: 0.9548
# Epoch 2/2... Discriminator Loss: 1.0193... Generator Loss: 0.7678
# Epoch 2/2... Discriminator Loss: 1.2265... Generator Loss: 0.5556
# Epoch 2/2... Discriminator Loss: 0.9846... Generator Loss: 1.5958
# Epoch 2/2... Discriminator Loss: 0.9666... Generator Loss: 2.0395
# Epoch 2/2... Discriminator Loss: 0.7929... Generator Loss: 1.1620
# Epoch 2/2... Discriminator Loss: 0.9177... Generator Loss: 2.0732
# Epoch 2/2... Discriminator Loss: 0.9767... Generator Loss: 1.3439
# Epoch 2/2... Discriminator Loss: 1.5688... Generator Loss: 2.9228
# Epoch 2/2... Discriminator Loss: 0.7907... Generator Loss: 1.1057
# Epoch 2/2... Discriminator Loss: 0.8053... Generator Loss: 1.2487
# Epoch 2/2... Discriminator Loss: 1.0269... Generator Loss: 1.9466
# Epoch 2/2... Discriminator Loss: 1.5072... Generator Loss: 1.2071
# Epoch 2/2... Discriminator Loss: 0.7245... Generator Loss: 1.6370
# Epoch 2/2... Discriminator Loss: 0.8897... Generator Loss: 0.8907
# Epoch 2/2... Discriminator Loss: 0.9610... Generator Loss: 1.5964
# Epoch 2/2... Discriminator Loss: 0.9303... Generator Loss: 0.8230
# Epoch 2/2... Discriminator Loss: 0.9264... Generator Loss: 0.8359
# Epoch 2/2... Discriminator Loss: 1.0333... Generator Loss: 0.8362
# Epoch 2/2... Discriminator Loss: 0.9888... Generator Loss: 1.2467
# Epoch 2/2... Discriminator Loss: 0.7045... Generator Loss: 1.4960
# Epoch 2/2... Discriminator Loss: 1.3374... Generator Loss: 0.4710
# Epoch 2/2... Discriminator Loss: 1.2977... Generator Loss: 0.4488
# Epoch 2/2... Discriminator Loss: 0.9337... Generator Loss: 1.0158
# Epoch 2/2... Discriminator Loss: 1.0823... Generator Loss: 0.7202
# Epoch 2/2... Discriminator Loss: 1.2452... Generator Loss: 0.4770
# Epoch 2/2... Discriminator Loss: 0.9812... Generator Loss: 1.6336
# Epoch 2/2... Discriminator Loss: 1.6489... Generator Loss: 0.3550

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.002
beta1 = 0.5



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 2.8099... Generator Loss: 0.0858
# Epoch 1/1... Discriminator Loss: 0.1561... Generator Loss: 4.7507
# Epoch 1/1... Discriminator Loss: 0.5726... Generator Loss: 8.8147
# Epoch 1/1... Discriminator Loss: 0.4178... Generator Loss: 2.7309
# Epoch 1/1... Discriminator Loss: 3.3703... Generator Loss: 1.6488
# Epoch 1/1... Discriminator Loss: 0.1995... Generator Loss: 2.5874
# Epoch 1/1... Discriminator Loss: 2.2724... Generator Loss: 7.6089
# Epoch 1/1... Discriminator Loss: 1.4305... Generator Loss: 4.6540
# Epoch 1/1... Discriminator Loss: 0.7195... Generator Loss: 1.0832
# Epoch 1/1... Discriminator Loss: 0.1423... Generator Loss: 2.9357
# Epoch 1/1... Discriminator Loss: 0.3022... Generator Loss: 1.8308
# Epoch 1/1... Discriminator Loss: 0.5371... Generator Loss: 0.9917
# Epoch 1/1... Discriminator Loss: 0.8076... Generator Loss: 0.9063
# Epoch 1/1... Discriminator Loss: 0.2742... Generator Loss: 1.9138
# Epoch 1/1... Discriminator Loss: 0.3762... Generator Loss: 3.0716
# Epoch 1/1... Discriminator Loss: 0.5484... Generator Loss: 2.3585
# Epoch 1/1... Discriminator Loss: 1.8239... Generator Loss: 0.3035
# Epoch 1/1... Discriminator Loss: 0.5972... Generator Loss: 1.1459
# Epoch 1/1... Discriminator Loss: 2.5001... Generator Loss: 0.1536
# Epoch 1/1... Discriminator Loss: 0.6050... Generator Loss: 2.1536
# Epoch 1/1... Discriminator Loss: 1.1697... Generator Loss: 3.6030
# Epoch 1/1... Discriminator Loss: 1.2053... Generator Loss: 0.8571
# Epoch 1/1... Discriminator Loss: 0.9098... Generator Loss: 1.0858
# Epoch 1/1... Discriminator Loss: 0.7882... Generator Loss: 1.2579
# Epoch 1/1... Discriminator Loss: 0.6165... Generator Loss: 1.3703
# Epoch 1/1... Discriminator Loss: 0.9123... Generator Loss: 1.1497
# Epoch 1/1... Discriminator Loss: 0.7878... Generator Loss: 0.9744
# Epoch 1/1... Discriminator Loss: 0.4042... Generator Loss: 1.5920
# Epoch 1/1... Discriminator Loss: 3.7292... Generator Loss: 5.9010
# Epoch 1/1... Discriminator Loss: 1.1867... Generator Loss: 0.5898
# Epoch 1/1... Discriminator Loss: 0.7818... Generator Loss: 1.1787
# Epoch 1/1... Discriminator Loss: 0.9904... Generator Loss: 2.1788
# Epoch 1/1... Discriminator Loss: 1.9939... Generator Loss: 0.8463
# Epoch 1/1... Discriminator Loss: 1.6251... Generator Loss: 0.5216
# Epoch 1/1... Discriminator Loss: 0.7692... Generator Loss: 1.2871
# Epoch 1/1... Discriminator Loss: 0.7454... Generator Loss: 1.5216
# Epoch 1/1... Discriminator Loss: 0.9684... Generator Loss: 1.1863
# Epoch 1/1... Discriminator Loss: 1.2118... Generator Loss: 0.8137
# Epoch 1/1... Discriminator Loss: 3.4058... Generator Loss: 0.0631
# Epoch 1/1... Discriminator Loss: 1.0047... Generator Loss: 1.0314
# Epoch 1/1... Discriminator Loss: 2.0842... Generator Loss: 3.5361
# Epoch 1/1... Discriminator Loss: 1.1524... Generator Loss: 0.5302
# Epoch 1/1... Discriminator Loss: 1.3406... Generator Loss: 0.5818
# Epoch 1/1... Discriminator Loss: 0.9678... Generator Loss: 1.0035
# Epoch 1/1... Discriminator Loss: 1.4836... Generator Loss: 0.6169
# Epoch 1/1... Discriminator Loss: 1.0233... Generator Loss: 1.0581
# Epoch 1/1... Discriminator Loss: 1.9287... Generator Loss: 0.2855
# Epoch 1/1... Discriminator Loss: 1.1512... Generator Loss: 1.2030
# Epoch 1/1... Discriminator Loss: 0.8877... Generator Loss: 1.3159
# Epoch 1/1... Discriminator Loss: 1.1333... Generator Loss: 1.0996
# Epoch 1/1... Discriminator Loss: 1.2658... Generator Loss: 1.2493
# Epoch 1/1... Discriminator Loss: 1.1270... Generator Loss: 0.7652
# Epoch 1/1... Discriminator Loss: 3.8605... Generator Loss: 4.7862
# Epoch 1/1... Discriminator Loss: 0.9620... Generator Loss: 1.1732
# Epoch 1/1... Discriminator Loss: 1.4137... Generator Loss: 2.3746
# Epoch 1/1... Discriminator Loss: 1.5731... Generator Loss: 2.9265
# Epoch 1/1... Discriminator Loss: 1.1826... Generator Loss: 2.4841
# Epoch 1/1... Discriminator Loss: 1.2082... Generator Loss: 0.6952
# Epoch 1/1... Discriminator Loss: 1.1398... Generator Loss: 2.0224
# Epoch 1/1... Discriminator Loss: 1.0577... Generator Loss: 0.6989
# Epoch 1/1... Discriminator Loss: 1.1394... Generator Loss: 1.4095
# Epoch 1/1... Discriminator Loss: 2.1191... Generator Loss: 0.1947
# Epoch 1/1... Discriminator Loss: 1.2410... Generator Loss: 2.1089
# Epoch 1/1... Discriminator Loss: 2.5269... Generator Loss: 3.9408
# Epoch 1/1... Discriminator Loss: 0.9365... Generator Loss: 1.9758
# Epoch 1/1... Discriminator Loss: 0.8867... Generator Loss: 0.9384
# Epoch 1/1... Discriminator Loss: 0.7450... Generator Loss: 1.1307
# Epoch 1/1... Discriminator Loss: 1.2504... Generator Loss: 1.3113
# Epoch 1/1... Discriminator Loss: 0.9816... Generator Loss: 1.2725
# Epoch 1/1... Discriminator Loss: 1.2692... Generator Loss: 1.1339
# Epoch 1/1... Discriminator Loss: 0.9524... Generator Loss: 1.2860
# Epoch 1/1... Discriminator Loss: 0.9211... Generator Loss: 0.9604
# Epoch 1/1... Discriminator Loss: 0.8379... Generator Loss: 2.1407
# Epoch 1/1... Discriminator Loss: 0.9975... Generator Loss: 2.0024
# Epoch 1/1... Discriminator Loss: 1.2484... Generator Loss: 0.5830
# Epoch 1/1... Discriminator Loss: 0.8210... Generator Loss: 0.8066
# Epoch 1/1... Discriminator Loss: 1.0536... Generator Loss: 1.3342
# Epoch 1/1... Discriminator Loss: 1.0500... Generator Loss: 1.1140
# Epoch 1/1... Discriminator Loss: 0.9250... Generator Loss: 0.7191
# Epoch 1/1... Discriminator Loss: 1.4193... Generator Loss: 0.4390
# Epoch 1/1... Discriminator Loss: 1.1822... Generator Loss: 1.8849
# Epoch 1/1... Discriminator Loss: 1.0535... Generator Loss: 1.0390
# Epoch 1/1... Discriminator Loss: 1.1363... Generator Loss: 0.6105
# Epoch 1/1... Discriminator Loss: 1.1052... Generator Loss: 0.6817
# Epoch 1/1... Discriminator Loss: 1.1644... Generator Loss: 1.1561
# Epoch 1/1... Discriminator Loss: 1.1406... Generator Loss: 0.6323
# Epoch 1/1... Discriminator Loss: 1.3345... Generator Loss: 1.2436
# Epoch 1/1... Discriminator Loss: 1.1741... Generator Loss: 0.5768
# Epoch 1/1... Discriminator Loss: 1.0678... Generator Loss: 0.7794
# Epoch 1/1... Discriminator Loss: 1.0638... Generator Loss: 0.8134
# Epoch 1/1... Discriminator Loss: 1.2752... Generator Loss: 0.8426
# Epoch 1/1... Discriminator Loss: 1.0982... Generator Loss: 0.6190
# Epoch 1/1... Discriminator Loss: 0.7422... Generator Loss: 1.4230
# Epoch 1/1... Discriminator Loss: 1.2255... Generator Loss: 0.8804
# Epoch 1/1... Discriminator Loss: 0.9594... Generator Loss: 0.7432
# Epoch 1/1... Discriminator Loss: 1.3499... Generator Loss: 1.8064
# Epoch 1/1... Discriminator Loss: 1.1738... Generator Loss: 1.3178
# Epoch 1/1... Discriminator Loss: 1.6380... Generator Loss: 0.4057
# Epoch 1/1... Discriminator Loss: 1.3604... Generator Loss: 0.8289
# Epoch 1/1... Discriminator Loss: 1.2280... Generator Loss: 0.5598
# Epoch 1/1... Discriminator Loss: 1.0973... Generator Loss: 0.7880
# Epoch 1/1... Discriminator Loss: 1.1337... Generator Loss: 1.5355
# Epoch 1/1... Discriminator Loss: 1.2032... Generator Loss: 0.5722
# Epoch 1/1... Discriminator Loss: 0.9202... Generator Loss: 1.5447
# Epoch 1/1... Discriminator Loss: 0.9453... Generator Loss: 1.0613
# Epoch 1/1... Discriminator Loss: 1.2335... Generator Loss: 0.6664
# Epoch 1/1... Discriminator Loss: 1.1352... Generator Loss: 2.0086
# Epoch 1/1... Discriminator Loss: 1.3671... Generator Loss: 0.6238
# Epoch 1/1... Discriminator Loss: 0.9180... Generator Loss: 0.8254
# Epoch 1/1... Discriminator Loss: 1.2243... Generator Loss: 0.6103
# Epoch 1/1... Discriminator Loss: 1.6830... Generator Loss: 3.0927
# Epoch 1/1... Discriminator Loss: 0.9527... Generator Loss: 0.8989
# Epoch 1/1... Discriminator Loss: 0.9355... Generator Loss: 1.4850
# Epoch 1/1... Discriminator Loss: 1.4379... Generator Loss: 0.5629
# Epoch 1/1... Discriminator Loss: 1.1218... Generator Loss: 1.0494
# Epoch 1/1... Discriminator Loss: 1.6905... Generator Loss: 2.5884
# Epoch 1/1... Discriminator Loss: 0.8904... Generator Loss: 1.1812
# Epoch 1/1... Discriminator Loss: 1.4137... Generator Loss: 0.4884
# Epoch 1/1... Discriminator Loss: 1.4280... Generator Loss: 2.6836
# Epoch 1/1... Discriminator Loss: 0.9725... Generator Loss: 1.1950
# Epoch 1/1... Discriminator Loss: 0.9337... Generator Loss: 0.8596
# Epoch 1/1... Discriminator Loss: 0.8910... Generator Loss: 1.0019
# Epoch 1/1... Discriminator Loss: 1.0024... Generator Loss: 0.9548
# Epoch 1/1... Discriminator Loss: 0.7856... Generator Loss: 1.2062
# Epoch 1/1... Discriminator Loss: 0.9080... Generator Loss: 1.2486
# Epoch 1/1... Discriminator Loss: 1.1491... Generator Loss: 1.1081
# Epoch 1/1... Discriminator Loss: 0.8688... Generator Loss: 2.1715
# Epoch 1/1... Discriminator Loss: 1.0349... Generator Loss: 1.2372
# Epoch 1/1... Discriminator Loss: 0.9769... Generator Loss: 1.2791
# Epoch 1/1... Discriminator Loss: 0.7547... Generator Loss: 1.2047
# Epoch 1/1... Discriminator Loss: 0.8492... Generator Loss: 2.1726
# Epoch 1/1... Discriminator Loss: 1.4582... Generator Loss: 2.0754
# Epoch 1/1... Discriminator Loss: 1.3367... Generator Loss: 1.0812
# Epoch 1/1... Discriminator Loss: 1.0606... Generator Loss: 1.2325
# Epoch 1/1... Discriminator Loss: 1.1404... Generator Loss: 2.6273
# Epoch 1/1... Discriminator Loss: 0.9444... Generator Loss: 1.1968
# Epoch 1/1... Discriminator Loss: 0.9657... Generator Loss: 1.7470
# Epoch 1/1... Discriminator Loss: 1.1879... Generator Loss: 0.7588
# Epoch 1/1... Discriminator Loss: 1.1769... Generator Loss: 0.5240
# Epoch 1/1... Discriminator Loss: 1.3871... Generator Loss: 0.5278
# Epoch 1/1... Discriminator Loss: 1.4119... Generator Loss: 0.4436
# Epoch 1/1... Discriminator Loss: 0.9924... Generator Loss: 1.1908
# Epoch 1/1... Discriminator Loss: 1.1251... Generator Loss: 0.6271
# Epoch 1/1... Discriminator Loss: 0.8856... Generator Loss: 1.0259
# Epoch 1/1... Discriminator Loss: 1.1015... Generator Loss: 0.9375
# Epoch 1/1... Discriminator Loss: 0.9479... Generator Loss: 1.4989
# Epoch 1/1... Discriminator Loss: 1.1358... Generator Loss: 0.9793
# Epoch 1/1... Discriminator Loss: 1.4666... Generator Loss: 0.4279
# Epoch 1/1... Discriminator Loss: 1.0137... Generator Loss: 0.8426
# Epoch 1/1... Discriminator Loss: 1.5088... Generator Loss: 0.3907
# Epoch 1/1... Discriminator Loss: 1.1372... Generator Loss: 0.8197
# Epoch 1/1... Discriminator Loss: 0.8998... Generator Loss: 1.2092
# Epoch 1/1... Discriminator Loss: 1.0394... Generator Loss: 1.0003
# Epoch 1/1... Discriminator Loss: 0.9963... Generator Loss: 1.3235
# Epoch 1/1... Discriminator Loss: 1.0006... Generator Loss: 1.2820
# Epoch 1/1... Discriminator Loss: 0.9721... Generator Loss: 1.1076
# Epoch 1/1... Discriminator Loss: 1.3818... Generator Loss: 0.4340
# Epoch 1/1... Discriminator Loss: 1.1788... Generator Loss: 0.9575

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
